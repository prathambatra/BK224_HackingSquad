# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
train=pd.read_csv('input.txt')
test=pd.read_csv('test.txt')
train=np.array(train)
test=np.array(test)
Xtrain=train[:,0:3]
Xtest=test[:,0:3]
Ytrain=train[:,3]
Ytest=test[:,3]

# %%
expr=[]
real=[]
foul=[]
for i in range(30):
    expr.append(i)
    real.append(.30)
    foul.append(.25)

# %%
plt.scatter(train[:,0],train[:,3])

# %%
plt.scatter(train[:,1],train[:,3])

# %%
plt.scatter(train[:,2],train[:,3])

# %%
from mpl_toolkits.mplot3d import axes3d
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')
ax1.scatter(Xtrain[:,0], Xtrain[:,1], Ytrain, c = 'm', marker = 'o')

# %%
reg = LinearRegression()

# %%
reg.fit(Xtrain,Ytrain)
# Out:
# LinearRegression()

# %%
from sklearn import ensemble
clf = ensemble.GradientBoostingRegressor(n_estimators = 400, max_depth = 5, min_samples_split = 2,
          learning_rate = 0.1, loss = 'ls')

# %%
clf.fit(Xtrain, Ytrain)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
result=clf.predict(Xtest)
result
# Out:
# array([0.32895894, 0.29536708, 0.2873454 , 0.28461502, 0.28461502,
#        0.28215384, 0.27544576, 0.27095882, 0.25968917, 0.25198374,
#        0.25041904, 0.24973497, 0.24973497, 0.2472026 , 0.2472026 ,
#        0.24677696, 0.24036269, 0.23970354, 0.21556845, 0.2095733 ,
#        0.2095733 , 0.20141237, 0.19507824, 0.19426905, 0.18710914,
#        0.18210477, 0.17068901, 0.17068901, 0.16759127, 0.13061346])

# %%
# out=open('newinput.txt','+w')
# for i in range(len(Xtest)):
#     line=str(Xtest[i][0])+", "+str(Xtest[i][1])+", "+str(Xtest[i][2])+", "+str(result[i])+"\n";
#     out.write(line)
# out.close()

# %%
plt.figure(figsize=(12, 6))
plt.plot(expr,result,'b-')
plt.plot(expr,real,'g-')
plt.plot(expr,foul,'r-')
plt.ylabel('Heat transfer coefficient')
plt.xlabel('Days')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
clf.score(Xtest,Ytest)
# Out:
# 0.9999994482997838
